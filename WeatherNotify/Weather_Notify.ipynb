# %%
import requests
from pathlib import Path
from datetime import datetime
import json
from googletrans import Translator

##url = 'https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}'

##url = str.format('api.openweathermap.org/data/2.5/weather?q=Puli,uk&APPID=5e7982dc6f9b409d80ba738747194be8') 
#url = str.format('https://api.openweathermap.org/data/2.5/weather?lat={}&lon={}&units=metric&appid={}',23.95,120.97,'5e7982dc6f9b409d80ba738747194be8')
url = str.format('https://api.openweathermap.org/data/2.5/forecast?id={}&units=metric&appid={}','1670310','5e7982dc6f9b409d80ba738747194be8')

def SetTextFile(file_name,data):
    ## 建立檔案
    file_path = Path(str.format('C:\work\\anaconda\TestProject\{0}',file_name))
    file_path.touch(exist_ok=True)
    
    
    open(file_path,'w').close()

    with open (file_path,'w') as file:
        file.write(str(data))
        file.close()
    
    ##delete file
    ##file_path.unlink()

    return


response = requests.get(url)
print('response_status_code',response.status_code)
if response.status_code == 200:
    response_data = response.json()
    print(response_data)
    slist =  response_data['list']
    print(slist)
    j = slist[0]['weather']
    str_main = j[0]['main'] #天氣概況
    str_desc = j[0]['description'] #天氣描述
    
    str_msg = str.format('今日天氣概況:{}-{}',str_main,str_desc)

    str_inpute = str_main
    if (str_inpute !=''):
        translator = Translator()
        result = translator.translate(str_inpute, dest='zh-tw')
        print(result)
    else:
        print('input non')
        print(str_msg)
    ##SetTextFile('weatherDate.txt',response_data)
# Out:
# response_status_code 200
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1738929600, 'main': {'temp': 17.46, 'feels_like': 17.12, 'temp_min': 14.22, 'temp_max': 17.46, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 932, 'humidity': 71, 'temp_kf': 3.24}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 40}, 'wind': {'speed': 1.08, 'deg': 93, 'gust': 0.98}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 12:00:00'}, {'dt': 1738940400, 'main': {'temp': 15.17, 'feels_like': 14.7, 'temp_min': 13.21, 'temp_max': 15.17, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 932, 'humidity': 75, 'temp_kf': 1.96}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 75}, 'wind': {'speed': 1.03, 'deg': 77, 'gust': 1.1}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 15:00:00'}, {'dt': 1738951200, 'main': {'temp': 12.97, 'feels_like': 12.41, 'temp_min': 12.97, 'temp_max': 12.97, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 931, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 83}, 'wind': {'speed': 0.77, 'deg': 88, 'gust': 0.58}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 18:00:00'}, {'dt': 1738962000, 'main': {'temp': 12.56, 'feels_like': 12.01, 'temp_min': 12.56, 'temp_max': 12.56, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 931, 'humidity': 82, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 95}, 'wind': {'speed': 0.56, 'deg': 336, 'gust': 0.39}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 21:00:00'}, {'dt': 1738972800, 'main': {'temp': 13.97, 'feels_like': 13.41, 'temp_min': 13.97, 'temp_max': 13.97, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 933, 'humidity': 76, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 98}, 'wind': {'speed': 0.36, 'deg': 300, 'gust': 0}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 00:00:00'}, {'dt': 1738983600, 'main': {'temp': 18.78, 'feels_like': 18.2, 'temp_min': 18.78, 'temp_max': 18.78, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 932, 'humidity': 57, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 48}, 'wind': {'speed': 2.7, 'deg': 283, 'gust': 1.48}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 03:00:00'}, {'dt': 1738994400, 'main': {'temp': 19.55, 'feels_like': 18.92, 'temp_min': 19.55, 'temp_max': 19.55, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 930, 'humidity': 52, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 60}, 'wind': {'speed': 3.08, 'deg': 279, 'gust': 1.9}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 06:00:00'}, {'dt': 1739005200, 'main': {'temp': 15.46, 'feels_like': 14.6, 'temp_min': 15.46, 'temp_max': 15.46, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 931, 'humidity': 59, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'clouds': {'all': 21}, 'wind': {'speed': 1.85, 'deg': 276, 'gust': 1.34}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 09:00:00'}, {'dt': 1739016000, 'main': {'temp': 10.55, 'feels_like': 9.67, 'temp_min': 10.55, 'temp_max': 10.55, 'pressure': 1023, 'sea_level': 1023, 'grnd_level': 933, 'humidity': 77, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 20}, 'wind': {'speed': 0.37, 'deg': 85, 'gust': 0.42}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-08 12:00:0 ...
# [{'dt': 1738929600, 'main': {'temp': 17.46, 'feels_like': 17.12, 'temp_min': 14.22, 'temp_max': 17.46, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 932, 'humidity': 71, 'temp_kf': 3.24}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 40}, 'wind': {'speed': 1.08, 'deg': 93, 'gust': 0.98}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 12:00:00'}, {'dt': 1738940400, 'main': {'temp': 15.17, 'feels_like': 14.7, 'temp_min': 13.21, 'temp_max': 15.17, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 932, 'humidity': 75, 'temp_kf': 1.96}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 75}, 'wind': {'speed': 1.03, 'deg': 77, 'gust': 1.1}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 15:00:00'}, {'dt': 1738951200, 'main': {'temp': 12.97, 'feels_like': 12.41, 'temp_min': 12.97, 'temp_max': 12.97, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 931, 'humidity': 80, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 83}, 'wind': {'speed': 0.77, 'deg': 88, 'gust': 0.58}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 18:00:00'}, {'dt': 1738962000, 'main': {'temp': 12.56, 'feels_like': 12.01, 'temp_min': 12.56, 'temp_max': 12.56, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 931, 'humidity': 82, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 95}, 'wind': {'speed': 0.56, 'deg': 336, 'gust': 0.39}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-07 21:00:00'}, {'dt': 1738972800, 'main': {'temp': 13.97, 'feels_like': 13.41, 'temp_min': 13.97, 'temp_max': 13.97, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 933, 'humidity': 76, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 98}, 'wind': {'speed': 0.36, 'deg': 300, 'gust': 0}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 00:00:00'}, {'dt': 1738983600, 'main': {'temp': 18.78, 'feels_like': 18.2, 'temp_min': 18.78, 'temp_max': 18.78, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 932, 'humidity': 57, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 48}, 'wind': {'speed': 2.7, 'deg': 283, 'gust': 1.48}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 03:00:00'}, {'dt': 1738994400, 'main': {'temp': 19.55, 'feels_like': 18.92, 'temp_min': 19.55, 'temp_max': 19.55, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 930, 'humidity': 52, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 60}, 'wind': {'speed': 3.08, 'deg': 279, 'gust': 1.9}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 06:00:00'}, {'dt': 1739005200, 'main': {'temp': 15.46, 'feels_like': 14.6, 'temp_min': 15.46, 'temp_max': 15.46, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 931, 'humidity': 59, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'clouds': {'all': 21}, 'wind': {'speed': 1.85, 'deg': 276, 'gust': 1.34}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-02-08 09:00:00'}, {'dt': 1739016000, 'main': {'temp': 10.55, 'feels_like': 9.67, 'temp_min': 10.55, 'temp_max': 10.55, 'pressure': 1023, 'sea_level': 1023, 'grnd_level': 933, 'humidity': 77, 'temp_kf': 0}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'clouds': {'all': 20}, 'wind': {'speed': 0.37, 'deg': 85, 'gust': 0.42}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-02-08 12:00:00'}, {'dt': 1739026800, 'main': {'temp': 9.6, 'f ...
# <coroutine object Translator.translate at 0x00000238E4644270>
# C:\Users\wratt\AppData\Local\Temp\ipykernel_29284\3263425456.py:47: RuntimeWarning: coroutine 'Translator.translate' was never awaited
#   result = translator.translate(str_inpute, dest='zh-tw')
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
